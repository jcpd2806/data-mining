# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/titanic.csv"
df = pd.read_csv(url)

print('Primeras cinco lineas: \n',df.head())
print('Descripcion: \n',df.describe())
# Out:
# Primeras cinco lineas:
#     PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# Descripcion:
#         PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# Promedio de fare mujeres: 44.47981783439487
# Promedio de fare mujeres: 25.523893414211418
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# Pregunta A: Observen la columna Fare (Tarifa del boleto). ¿Cuál es la diferencia matemática entre el percentil 75% (el tercer cuartil) y el valor Máximo (max)? Como ingenieros de software, ¿qué les dice esta enorme dispersión estadística sobre la homogeneidad de los precios que se cobraron en el barco? \
# -> 481.3292
#
# Pregunta B: Revisen la fila count (conteo total de registros válidos) de las distintas columnas en el resultado de su .describe(). Comparen el conteo de la columna PassengerId con el conteo de la columna Age. ¿Qué anomalía de base de datos acaban de descubrir? \
# -> Debe de haber valores nulos que no se toman en cuenta dentro de la base de datos
#
# Pregunta C: El algoritmo que construirán al final del semestre requiere que todos los pasajeros tengan un valor numérico en la columna Age para poder compilar. Sabiendo lo que acaban de descubrir en la Pregunta B, propongan al menos dos estrategias a nivel de base de datos o de programación para resolver este problema antes de alimentar a la IA. \
# -> **Primer Estrategia** \
# Se podrian llenar los valores nulos con los valores de la mediana. \
#
# -> **Segunda Estrategia** \
# Se podrian eliminar los valores nulos, pero en ese caso el dataset tendria un sesgo o no mantendria un promedio que se ajuste a la realidad

# %% [markdown]
# Cual fue la tarifa promedio que pagaron las mujeres?
#
# Y cual fue de la de los hombres

# %%
avg_fare_female: 0
avg_fare_male: 0

total_fare_women = 0
total_fare_men = 0
women = 0
men = 0

for row in df.iterrows():

    if row[1]['Sex'] == 'female':
        women += 1
        total_fare_women += row[1]['Fare']
    elif row[1]['Sex'] == 'male':
        men += 1
        total_fare_men += row[1]['Fare']

avg_fare_female = total_fare_women / women
avg_fare_male = total_fare_men / men

print(f"Promedio de fare mujeres: {avg_fare_female}")
print(f"Promedio de fare mujeres: {avg_fare_male}")
# Out:
# Promedio de fare mujeres: 44.47981783439487
# Promedio de fare mujeres: 25.523893414211418

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
fare_IQR = df['Fare'].quantile(0.75) - df['Fare'].quantile(0.25)

outlier_count = 0

for row in df.iterrows():
    if row[1]['Fare'] < (df['Fare'].quantile(0.25) - 1.5 * fare_IQR) or row[1]['Fare'] > (df['Fare'].quantile(0.75) + 1.5 * fare_IQR):
        outlier_count += 1

print("Number of outliers: ", outlier_count)
# Out:
# Number of outliers:  116
